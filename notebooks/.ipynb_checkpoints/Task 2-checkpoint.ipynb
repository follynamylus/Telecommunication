# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from kneed import KneeLocator
plt.style.use("fivethirtyeight")

# %% [markdown]
# Read in Data

# %%
df = pd.read_csv('telco.csv')

# %%
df.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# 2                D42335A  ...          19725661.0          14699576.0
# 3                T21824A  ...          21388122.0          15146643.0
# 4                D88865A  ...          15259380.0          18962873.0
#
#    Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
#
#    Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
#
#    Total DL (Bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
#
# [5 rows x 55 columns]

# %% [markdown]
# Drop rows with missing values in MSISDN/Number and Bearer Id

# %%
df = df[df['MSISDN/Number'].notna()]

# %%
df = df[df['Bearer Id'].notna()]

# %%
df = df.reset_index()

# %% [markdown]
# Sort columns to Numerical and Categorical

# %%
num_cols = []
categorical_cols = []

# %%
def sort_cols(data):


    for i in data.columns:
        if data[i].dtypes == "object":
            categorical_cols.append(i)
        else :
            num_cols.append(i)

# %%
sort_cols(df)
Df = df.copy()

# %% [markdown]
# Scale Data using Standard Scaler

# %%
df[num_cols] = StandardScaler().fit_transform(df[num_cols])

# %% [markdown]
# Fix missing values

# %%
def fix_cat_cols(data,cat_columns):
    for i in cat_columns:
        data[i] = data[i].fillna(data[i].mode()[0])

# %%
fix_cat_cols(df,categorical_cols)

# %%
def fix_num_cols(data,num_columns):
    for i in num_columns:
        data[i] = data[i].fillna(data[i].mean())

# %%
fix_num_cols(df,num_cols)

# %% [markdown]
# # Task 2

# %% [markdown]
# Marge Total download and upload to form total volume

# %%
df['Total_volume (Bytes)'] = df['Total DL (Bytes)'] + df['Total UL (Bytes)']

# %% [markdown]
# Generate session frequency

# %%
df['Session frequency'] = df.groupby(['Bearer Id'])['Dur. (ms)'].transform('count')

# %% [markdown]
# Output dataframe for top ten frequency

# %%
df['Session frequency'].value_counts()
# Out:
# 1     122552
# 2      19568
# 3       4503
# 4       1200
# 5        355
# 6        150
# 7         84
# 9         36
# 8         32
# 16        16
# 10        10
# Name: Session frequency, dtype: int64

# %%
df['Session frequency'].value_counts().nlargest(10)
# Out:
# 1     122552
# 2      19568
# 3       4503
# 4       1200
# 5        355
# 6        150
# 7         84
# 9         36
# 8         32
# 16        16
# Name: Session frequency, dtype: int64

# %%
groups = []

# %%
new_df = df.loc[df['Session frequency']!=10, :]

# %%
new_df
# Out:
#            index  Bearer Id            Start  Start ms              End  \
# 0      -1.736517   1.025741   4/4/2019 12:01  0.938428  4/25/2019 14:35
# 1      -1.736494   1.025741   4/9/2019 13:04 -0.915592   4/25/2019 8:15
# 2      -1.736471   1.025741   4/9/2019 17:42 -1.726509  4/25/2019 11:58
# 3      -1.736448   1.025741   4/10/2019 0:31 -0.045762   4/25/2019 7:36
# 4      -1.736425   1.025741  4/12/2019 20:10  0.228009  4/25/2019 10:40
# ...          ...        ...              ...       ...              ...
# 148501  1.729278   1.000835   4/29/2019 7:28  0.401282   4/30/2019 0:01
# 148502  1.729301  -0.991594   4/29/2019 7:28 -0.167053   4/30/2019 6:02
# 148503  1.729324  -0.966689   4/29/2019 7:28 -0.056158  4/30/2019 10:41
# 148504  1.729347   1.025741   4/29/2019 7:28 -0.749250  4/30/2019 10:46
# 148505  1.729370   1.025741   4/29/2019 7:28  0.681984  4/30/2019 10:40
#
#           End ms  Dur. (ms)      IMSI  MSISDN/Number      IMEI  ...  \
# 0       0.567085  21.197923 -0.009961      -0.003363 -0.578612  ...
# 1       0.372688  15.541897  0.020290      -0.003356 -0.566451  ...
# 2       0.532371  15.500675 -0.084329      -0.003324 -0.589297  ...
# 3      -1.137366  15.004168 -0.012962      -0.003328 -0.585950  ...
# 4       1.580731  12.136364 -0.013022      -0.003348 -0.583703  ...
# ...          ...        ...       ...            ...       ...  ...
# 148501 -0.318119  -0.561190 -0.012944      -0.003361 -0.587024  ...
# 148502 -0.988097  -0.294231  0.039445      -0.003368 -0.580310  ...
# 148503 -1.081824  -0.087749  0.020221      -0.003363 -0.572402  ...
# 148504  1.080851  -0.084308  0.007298      -0.003380 -0.569696  ...
# 148505 -0.595830  -0.088489  0.032878      -0.003381  1.679982  ...
#
#        Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0               -0.509787           -0.211650          -0.590081
# 1                0.997948            0.979132           0.765095
# 2                0.886331           -0.761020          -0.788840
# 3                0.352032           -1.557739           1.547002
# 4                0.817452           -1.665121           0.432957
# ...                   ...                 ...                ...
# 148501           1.612162           -0.605887           1.485106
# 148502           0.930333            1.364640           0.428459
# 148503           1.148392            1.618653           0.839451
# 148504          -0.247332           -0.933663           0.538825
# 148505          -1.234948            0.341415          -0.284944
#
#         Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# 0                1.266126         -1.025682          0.115691
# 1               -1.488700          0.434901          1.424357
# 2               -1.650784         -0.043016         -0.848627
# 3                0.535372          1.348426          0.950891
# 4               -0.995368          0.532799          1.184291
# ...                   ...               ...               ...
# 148501           0.927477         -0.410298          1.389829
# 148502           0.189799         -1.718550          1.095609
# 148503          -0.743330          1.196842         -1.217275
# 148504           1.067497         -1.233952          0.640004
# 148505          -1.204555          1.618505         -1.437630
#
#         Total UL (Bytes)  Total DL (Bytes)  Total_volume (Bytes)  \
# 0              -0.387434         -0.597041             -0.984474
# 1               1.124363          0.813836              1.938198
# 2              -1.173547         -0.716103             -1.889650
# 3               0.195493          1.602782              1.798275
# 4              -0.228451          0.468816              0.240365
# ...                  ...               ...                   ...
# 148501          1.119486          1.492158              2.611644
# 148502          1.463813          0.489443              1.953256
# 148503         -0.175937          0.868156              0.692219
# 148504         -0.550357          0.565662              0.015305
# 148505         -1.019052         -0.338966             -1.358018
#
#         Session frequency
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 148501                  1
# 148502                  1
# 148503                  1
# 148504                  2
# 148505                  2
#
# [148496 rows x 58 columns]

# %% [markdown]
# ## Task 2.1

# %% [markdown]
# Get Important columns for engagement Metrics

# %%
user_per_MSISDN = new_df.groupby(['Session frequency',"Dur. (ms)",'Total_volume (Bytes)']).agg({'MSISDN/Number':'count'}).reset_index()

# %%
X = df[['Session frequency','Dur. (ms)','Total_volume (Bytes)']]

# %%
col_names = ["Session frequency","Dur. (ms)",'Total_volume (Bytes)']

# %%
df[col_names]
# Out:
#         Session frequency  Dur. (ms)  Total_volume (Bytes)
# 0                       1  21.197923             -0.984474
# 1                       1  15.541897              1.938198
# 2                       1  15.500675             -1.889650
# 3                       1  15.004168              1.798275
# 4                       1  12.136364              0.240365
# ...                   ...        ...                   ...
# 148501                  1  -0.561190              2.611644
# 148502                  1  -0.294231              1.953256
# 148503                  1  -0.087749              0.692219
000000
#
# [8 rows x 53 columns]

# %% [markdown]
# Sort the metrics into 3 different categories using Kmeans clustering.

# %%
kmeans = KMeans(
    init= "random",
    n_clusters = 3,
    n_init= 10,
    max_iter= 300,
    random_state= 42
)

# %%
kmeans.fit(X)
# Out:
# KMeans(init='random', n_clusters=3, random_state=42)

# %% [markdown]
# Assign the labels as a column in the Dataframe

# %%
X['labels'] = kmeans.labels_
# Out:
# C:\Users\CLASSISH\AppData\Local\Temp/ipykernel_8432/3168574615.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['labels'] = kmeans.labels_

# %%
X
# Out:
#         Session frequency  Dur. (ms)  Total_volume (Bytes)  labels
# 0                       1  21.197923             -0.984474       0
# 1                       1  15.541897              1.938198       0
# 2                       1  15.500675             -1.889650       0
# 3                       1  15.004168              1.798275       0
# 4                       1  12.136364              0.240365       0
# ...                   ...        ...                   ...     ...
# 148501                  1  -0.561190              2.611644       1
# 148502                  1  -0.294231              1.953256       1
# 148503                  1  -0.087749              0.692219       1
# 148504                  2  -0.084308              0.015305       1
# 148505                  2  -0.088489             -1.358018       2
#
# [148506 rows x 4 columns]

# %%
df['label'] = X["labels"]

# %% [markdown]
# Generate new dataframes from the clustered dataframe according to cluster label.

# %%
X1 = df[df.label==1]

# %%
X2 = df[df.label==2]

# %%
X0 = df[df.label==0]

# %% [markdown]
# Get the summary Statistics of the three generated dataframes.

# %%
X1.describe()
# Out:
#               index     Bearer Id      Start ms        End ms     Dur. (ms)  \
# count  69192.000000  69192.000000  69192.000000  69192.000000  69192.000000
# mean      -0.003607     -0.000163     -0.005478     -0.004631     -0.178730
# std        1.002425      1.000412      1.000140      1.001288      0.595860
# min       -1.734276     -1.116121     -1.729974     -1.730974     -1.208031
# 25%       -0.859607     -0.966689     -0.870541     -0.870070     -0.620325
# 50%       -0.008992     -0.966689     -0.007642     -0.009165     -0.230473
# 75%        0.861287      1.000835      0.858722      0.869096      0.149397
# max        1.729347      1.050646      1.732018      1.736943      2.379685
#
#                IMSI  MSISDN/Number          IMEI  Avg RTT DL (ms)  \
# count  69192.000000   69192.000000  69192.000000     6.919200e+04
# mean       0.003424      -0.003359      0.016262    -1.319567e-03
# std        0.087463       0.000018      1.009502     8.272666e-01
# min       -0.098323      -0.003389     -2.108844    -1.808992e-01
# 25%       -0.013032      -0.003368     -0.580488    -1.212808e-01
# 50%       -0.003517      -0.003363     -0.569366    -8.891648e-02
# 75%        0.011261      -0.003355      1.680370     7.825846e-18
# max        3.317321      -0.003312      2.251262     1.099258e+02
#
#        Avg RTT UL (ms)  ...  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# count     6.919200e+04  ...        69192.000000       69192.000000
# mean      3.960716e-03  ...            0.311266           0.619269
# std       9.454995e-01  ...            0.950479           0.790320
# min      -2.079925e-01  ...           -1.730422          -1.728732
# 25%      -1.725960e-01  ...           -0.423929           0.099609
# 50%      -1.254007e-01  ...            0.442953           0.757518
# 75%       2.098302e-17  ...            1.130460           1.273379
# max       6.376526e+01  ...            1.731710           1.726933
#
#        Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# count       69192.000000      69192.000000      69192.000000
# mean            0.232342         -0.000971          0.226339
# std             0.974346          0.999328          0.973291
# min            -1.733459         -1.731916         -1.732626
# 25%            -0.556983         -0.869201         -0.557878
# 50%             0.340632          0.000065          0.327573
# 75%             1.083643          0.863243          1.071481
# max             1.729251          1.736637          1.739662
#
#        Total UL (Bytes)  Total DL (Bytes)  Total_volume (Bytes)  \
# count      69192.000000      69192.000000          69192.000000
# mean           0.551670          0.619624              1.171294
# std            0.838799          0.790235              0.825553
# min           -1.761239         -1.809379              0.005171
# 25%           -0.051254          0.099632              0.496576
# 50%            0.546536          0.757077              1.031071
# 75%            1.145182          1.273109              1.699789
# max            3.299398          1.835977              4.759514
#
#        Session frequency    label
# count       69192.000000  69192.0
# mean            1.240418      1.0
# std             0.617297      0.0
# min             1.000000      1.0
# 25%             1.000000      1.0
# 50%             1.000000      1.0
# 75%             1.000000      1.0
# max            16.000000      1.0
#
# [8 rows x 54 columns]

# %%
X0.describe()
# Out:
#              index    Bearer Id     Start ms       End ms    Dur. (ms)  \
# count  9618.000000  9618.000000  9618.000000  9618.000000  9618.000000
# mean      0.060140    -0.005986     0.004015     0.007881     2.599462
# std       0.940311     0.994722     0.996465     1.000624     1.773791
# min      -1.736517    -1.116121    -1.729974    -1.730974     0.970723
# 25%      -1.077035    -0.966689    -0.839352    -0.856184     1.642456
# 50%       0.578792    -0.966689     0.009685     0.042906     1.981393
# 75%       1.156126     1.025741     0.858722     0.876039     2.943261
# max       1.335111     1.025741     1.732018     1.736943    21.638073
#
#               IMSI  MSISDN/Number         IMEI  Avg RTT DL (ms)  \
# count  9618.000000    9618.000000  9618.000000     9.618000e+03
# mean     -0.046927       0.048501    -0.235645    -4.326331e-02
# std       3.915563       3.929315     0.811363     5.761848e-01
# min    -272.543237      -0.003389    -0.594919    -1.740856e-01
# 25%      -0.038722      -0.003368    -0.583779    -1.229841e-01
# 50%      -0.003525      -0.003363    -0.573222    -7.528942e-02
# 75%       0.011291      -0.003353    -0.561556     7.825846e-18
# max       0.541274     360.002802     2.251262     4.194887e+01
#
#        Avg RTT UL (ms)  ...  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# count     9.618000e+03  ...         9618.000000        9618.000000
# mean     -1.654832e-02  ...           -0.018826          -0.012349
# std       8.479695e-01  ...            0.987757           0.955403
# min      -2.079925e-01  ...           -1.728550          -1.729521
# 25%      -1.843948e-01  ...           -0.862571          -0.807237
# 50%      -1.136019e-01  ...           -0.030895          -0.022077
# 75%       2.098302e-17  ...            0.822199           0.780258
# max       2.567864e+01  ...            1.731677           1.726625
#
#        Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# count        9618.000000       9618.000000       9618.000000
# mean           -0.003882          0.001079         -0.004059
# std             0.993331          0.997757          0.995003
# min            -1.732767         -1.731836         -1.732566
# 25%            -0.854851         -0.856767         -0.866652
# 50%            -0.008655          0.006581          0.003073
# 75%             0.854246          0.853148          0.848268
# max             1.729075          1.736331          1.739024
#
#        Total UL (Bytes)  Total DL (Bytes)  Total_volume (Bytes)  \
# count       9618.000000       9618.000000           9618.000000
# mean          -0.016699         -0.012095             -0.028794
#
# [8 rows x 54 columns]

# %% [markdown]
# Visual Interpretation of results with accompanying texts

# %%
cols_plot = ['Dur. (ms)','Total_volume (Bytes)','Session frequency']

# %%
def box_plot(data, columns):
    for cols in columns:
        sns.boxplot(data=data, x= cols )
        plt.show()

# %%
box_plot(data= X0, columns= cols_plot)

# %%
box_plot(X1, cols_plot)

# %%
box_plot(X2,cols_plot)

# %% [markdown]
# Cluster 1 and 2 are of closer distance than cluster 0 which catches higher values of the metrics and will be located at upper right corner of the graph.

# %% [markdown]
# Get the top three most used applications.

# %%
Df['Social Media data'] = Df['Social Media DL (Bytes)'] + Df['Social Media UL (Bytes)']
Df['Google data'] = Df['Google DL (Bytes)'] + Df['Google UL (Bytes)']
Df['Email data'] = Df['Email DL (Bytes)'] + Df['Email UL (Bytes)']
Df['Youtube data'] = Df['Youtube DL (Bytes)'] + Df['Youtube UL (Bytes)']
Df['Netflix data'] = Df['Netflix DL (Bytes)'] + Df['Netflix UL (Bytes)']
Df['Gaming data'] = Df['Gaming DL (Bytes)'] + Df['Gaming UL (Bytes)']
Df['Other data'] = Df['Other DL (Bytes)'] + Df['Other UL (Bytes)']

# %%
Df['User per Social'] = Df.groupby(['MSISDN/Number'])['Social Media data'].transform('sum')
Df['User per Google'] = Df.groupby(['MSISDN/Number'])['Google data'].transform('sum')
Df['User per Email'] = Df.groupby(['MSISDN/Number'])['Email data'].transform('sum')
Df['User per Youtube'] = Df.groupby(['MSISDN/Number'])['Youtube data'].transform('sum')
Df['User per Netflix'] = Df.groupby(['MSISDN/Number'])['Netflix data'].transform('sum')
Df['User per Gaming'] = Df.groupby(['MSISDN/Number'])['Gaming data'].transform('sum')
Df['User per Other'] = Df.groupby(['MSISDN/Number'])['Other data'].transform('sum')

# %%
Df
# Out:
#          index     Bearer Id            Start  Start ms              End  \
# 0            0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35
# 1            1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15
# 2            2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58
# 3            3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36
# 4            4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40
# ...        ...           ...              ...       ...              ...
# 148501  149995  1.304243e+19   4/29/2019 7:28     615.0   4/30/2019 0:01
# 148502  149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02
# 148503  149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41
# 148504  149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46
# 148505  149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40
#
#         End ms  Dur. (ms)          IMSI  MSISDN/Number          IMEI  ...  \
# 0        662.0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13  ...
# 1        606.0  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13  ...
# 2        652.0  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13  ...
# 3        171.0  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13  ...
# 4        954.0  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13  ...
# ...        ...        ...           ...            ...           ...  ...
# 148501   407.0    59587.0  2.082014e+14   3.366865e+10  3.533251e+13  ...
# 148502   214.0    81230.0  2.082022e+14   3.365069e+10  3.548311e+13  ...
# 148503   187.0    97970.0  2.082019e+14   3.366345e+10  3.566051e+13  ...
# 148504   810.0    98249.0  2.082017e+14   3.362189e+10  3.572121e+13  ...
# 148505   327.0    97910.0  2.082021e+14   3.361962e+10  8.618620e+13  ...
#
#        Netflix data  Gaming data   Other data  User per Social  \
# 0        17855187.0  292426453.0  180558843.0        2771612.0
# 1        35565545.0  609920783.0  541959383.0        3469123.0
# 2        23751202.0  229980251.0  414908351.0        1726277.0
# 3        15092588.0  810387875.0  761837216.0         657493.0
# 4        17539799.0  531237049.0  564619822.0         912788.0
# ...             ...          ...          ...              ...
# 148501   29618711.0  797160102.0  336273648.0         993175.0
# 148502   37561864.0  535806880.0   16751926.0        3517065.0
# 148503   40643294.0  631628095.0  714638145.0        3503158.0
# 148504   15029702.0  566933800.0  132415585.0        1260239.0
# 148505   16494842.0  355066446.0  816120043.0         823109.0
#
#         User per Google  User per Email  User per Youtube  User per Netflix  \
# 0             3905804.0       6932608.0        46397870.0        30361399.0
# 1            12038408.0       3146166.0        52065276.0        54559509.0
# 2            10229119.0       3363124.0        34425237.0        23751202.0
# 3            11811761.0       2070983.0        36534765.0        15092588.0
# 4             7748843.0       2110349.0        34222253.0        17539799.0
# ...                 ...             ...               ...               ...
# 148501        1265634.0       4280107.0        24553645.0        29618711.0
# 148502       12784914.0        690876.0        27955095.0        37561864.0
# 148503       15877800.0       3246996.0        33312169.0        53796384.0
# 148504        6585469.0       2058277.0        24516413.0        15029702.0
# 148505        7757267.0       2850914.0        17122508.0        16494842.0
#
#         User per Gaming  User per Other
# 0          5.189561e+08    4.998505e+08
# 1          7.903986e+08    1.097356e+09
# 2          2.299803e+08    4.149084e+08
# 3          8.103879e+08    7.618372e+08
# 4          5.312370e+08    5.646198e+08
# ...                 ...             ...
# 148501     7.971601e+08    3.362736e+08
# 148502     5.358069e+08    1.675193e+07
# 148503     1.470909e+09    1.494133e+09
# 148504     5.669338e+08    1.324156e+08
# 148505     3.550664e+08    8.161200e+08
#
# [148506 rows x 70 columns]

# %%
User_per_app = ['User per Social','User per Google','User per Email','User per Youtube','User per Netflix','User per Gaming','User per Other']

# %%
for i in User_per_app :
    print(f'{i} : {Df[i].sum()}')
# Out:
# User per Social : 504799681793.0
# User per Google : 2160641369533.0
# User per Email : 625050518259.0
# User per Youtube : 6262520716907.0
# User per Netflix : 6258542853726.0
# User per Gaming : 118759250842853.0
# User per Other : 118615677410416.0

# %%
df['Youtube data'] = df['Youtube DL (Bytes)'] + df['Youtube UL (Bytes)']
df['Gaming data'] = df['Gaming DL (Bytes)'] + df['Gaming UL (Bytes)']
df['Other data'] = df['Other DL (Bytes)'] + df['Other UL (Bytes)']

# %%
top_3_apps = ["Gaming data","Other data","Youtube data"]

# %% [markdown]
# Plot top three most used applications using appropriate charts

# %%
for i in top_3_apps:
    sns.scatterplot(data=df, x='MSISDN/Number',y=i)
    plt.show()
    sns.boxplot(data=df, x= i )
    plt.show()
    sns.kdeplot(data=df, x= i)
    plt.show()

# %% [markdown]
# Sort using Kmeans clustering to K different clusters

# %%
kmeans_kwargs ={
    'init': "random",
    'n_init': 10,
    'max_iter': 300,
    'random_state': 42
}

# %%
sse = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, **kmeans_kwargs)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)

# %% [markdown]
# Check for optimized number of clusters using the elbow method then interprete the findings.

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(1,11),sse)
plt.xticks(range(1,11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %% [markdown]
# - The Optimized value for k is 2

# %% [markdown]
# - Deduced a steep slope k is from 1 till 2, then the slope starts to flatten out from k = 3 till 10 where the slope stopped
