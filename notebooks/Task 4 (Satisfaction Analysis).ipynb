# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from kneed import KneeLocator
from numpy.linalg import norm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score
import sqlite3 as sql

# %% [markdown]
# Read  in Data

# %%
df = pd.read_csv('telco.csv')

# %% [markdown]
# Drop instances with missing values either in MSISDN/Number or Bearer Id

# %%
df = df[df['MSISDN/Number'].notna()]

# %%
df = df[df['Bearer Id'].notna()]

# %%
df = df.reset_index()

# %% [markdown]
# Sort Columns to numerical and categorical

# %%
num_cols = []
categorical_cols = []

# %%
def sort_cols(data):


    for i in data.columns:
        if data[i].dtypes == "object":
            categorical_cols.append(i)
        else :
            num_cols.append(i)

# %%
sort_cols(df)

# %%
def fix_cat_cols(data,cat_columns):
    for i in cat_columns:
        data[i] = data[i].fillna(data[i].mode()[0])

# %%
fix_cat_cols(df,categorical_cols)

# %%
def fix_num_cols(data,num_columns):
    for i in num_columns:
        data[i] = data[i].fillna(data[i].mean())

# %%
fix_num_cols(df,num_cols)

# %% [markdown]
# Scale numerical columns using standard scaler.

# %%
df[num_cols] = StandardScaler().fit_transform(df[num_cols])

# %% [markdown]
# # Task 4

# %% [markdown]
# Generate engagement features

# %%
df['Total_volume (Bytes)'] = df['Total DL (Bytes)'] + df['Total UL (Bytes)']

# %%
df['Session frequency'] = df.groupby(['Bearer Id'])['Dur. (ms)'].transform('count')

# %%
df['AVG RTT (ms)'] = df['Avg RTT DL (ms)'] + df['Avg RTT UL (ms)']
df['Avg Bearer TP (kbps)'] = df['Avg Bearer TP DL (kbps)'] + df['Avg Bearer TP UL (kbps)']
df['TCP Retrans. Vol (Bytes)'] = df['TCP DL Retrans. Vol (Bytes)'] + df['TCP UL Retrans. Vol (Bytes)']

# %%
needed_cols = ['Avg RTT DL (ms)','Avg RTT UL (ms)','Avg Bearer TP DL (kbps)','Avg Bearer TP UL (kbps)','TCP DL Retrans. Vol (Bytes)','TCP UL Retrans. Vol (Bytes)',"Dur. (ms)",'Total_volume (Bytes)']

# %% [markdown]
# Fix outliers in numerical columns

# %%
for _ in needed_cols:
    Q1 = df[_].quantile(0.05)
    Q3 = df[_].quantile(0.95)

    df[_] = np.where(df[_] < Q1, df[_].mean(), df[_] )
    df[_] = np.where(df[_] > Q3, df[_].mean(), df[_] )
    print(df[_].skew())
# Out:
# 0.744336465155893
# 0.8871263872840702
# 1.5683406246562435
# 2.8292960770832267
# -0.8799218231536895
# -1.0479368331422163
# 0.6267722550599922
# -0.018707229171748746

# %% [markdown]
# Store engagement metrics in column X

# %%
X = df[['Session frequency','Dur. (ms)','Total_volume (Bytes)']]

# %%
df.describe()
# Out:
#               index     Bearer Id      Start ms        End ms      Dur. (ms)  \
# count  1.485060e+05  1.485060e+05  1.485060e+05  1.485060e+05  148506.000000
# mean   6.124296e-17 -4.561644e-16  7.657762e-17 -4.475999e-17      -0.090620
# std    1.000003e+00  1.000003e+00  1.000003e+00  1.000003e+00       0.561425
# min   -1.736517e+00 -1.116121e+00 -1.729974e+00 -1.730974e+00      -1.047212
# 25%   -8.630556e-01 -9.666889e-01 -8.636097e-01 -8.596554e-01      -0.380642
# 50%   -2.094556e-03 -9.666889e-01 -7.109151e-04  4.720407e-03      -0.230461
# 75%    8.673002e-01  1.000835e+00  8.656534e-01  8.690962e-01       0.143047
# max    1.729370e+00  1.050646e+00  1.732018e+00  1.736943e+00       1.688674
#
#                IMSI  MSISDN/Number          IMEI  Avg RTT DL (ms)  \
# count  1.485060e+05   1.485060e+05  1.485060e+05    148506.000000
# mean  -1.247852e-12  -1.525093e-19  3.487021e-16        -0.067472
# std    1.000003e+00   1.000003e+00  1.000003e+00         0.070952
# min   -2.725432e+02  -3.388678e-03 -2.142496e+00        -0.157090
# 25%   -1.303239e-02  -3.368152e-03 -5.813090e-01        -0.130656
# 50%   -3.515589e-03  -3.363094e-03 -5.696471e-01        -0.089118
# 75%    1.126367e-02  -3.355012e-03  1.677018e+00         0.000000
# max    3.317321e+00   3.600028e+02  2.251262e+00         0.214866
#
#        Avg RTT UL (ms)  ...  Gaming UL (Bytes)  Other DL (Bytes)  \
# count    148506.000000  ...       1.485060e+05      1.485060e+05
# mean         -0.080535  ...      -2.062165e-17      4.265476e-17
# std           0.119756  ...       1.000003e+00      1.000003e+00
# min          -0.217451  ...      -1.733506e+00     -1.731962e+00
# 25%          -0.178220  ...      -8.697119e-01     -8.671063e-01
# 50%          -0.112833  ...       4.286774e-04      2.916946e-03
# 75%           0.000000  ...       8.663118e-01      8.655972e-01
# max           0.344870  ...       1.729251e+00      1.736653e+00
#
#        Other UL (Bytes)  Total UL (Bytes)  Total DL (Bytes)  \
# count      1.485060e+05      1.485060e+05      1.485060e+05
# mean       7.827616e-17     -2.451632e-16      1.090890e-16
# std        1.000003e+00      1.000003e+00      1.000003e+00
# min       -1.732628e+00     -3.391657e+00     -1.832882e+00
# 25%       -8.636376e-01     -7.005508e-01     -8.663250e-01
# 50%        6.984898e-04      2.002651e-03      5.228838e-03
# 75%        8.634914e-01      7.016198e-01      8.644919e-01
# max        1.739672e+00      3.299398e+00      1.835977e+00
#
#        Total_volume (Bytes)  Session frequency  AVG RTT (ms)  \
# count          1.485060e+05      148506.000000  1.485060e+05
# mean           7.218246e-03           1.240327  2.234411e-17
# std            1.090028e+00           0.638478  1.419633e+00
# min           -2.323021e+00           1.000000 -4.310445e-01
# 25%           -7.785400e-01           1.000000 -3.090154e-01
# 50%           -1.374139e-16           1.000000 -2.041186e-01
# 75%            7.823430e-01           1.000000  0.000000e+00
# max            2.322077e+00          16.000000  1.825823e+02
#
#        Avg Bearer TP (kbps)  TCP Retrans. Vol (Bytes)
# count          1.485060e+05              1.485060e+05
# mean          -5.081252e-17             -6.741510e-17
# std            1.765438e+00              1.420845e+00
# min           -9.361938e-01             -2.279397e-01
# 25%           -9.242018e-01             -1.793037e-01
# 50%           -9.200605e-01             -6.359696e-17
# 75%            3.015852e-01             -6.359696e-17
# max            2.100730e+01              1.832445e+02
#
# [8 rows x 56 columns]

# %% [markdown]
# Use of Kmeans to seperate Engagement metrics to 3 clusters

# %%
kmeans = KMeans(
    init= "random",
    n_clusters = 3,
    n_init= 10,
    max_iter= 300,
    random_state= 42
)

# %%
kmeans.fit(X)
# Out:
# KMeans(init='random', n_clusters=3, random_state=42)

# %%
X['Engagement_labels'] = kmeans.labels_
# Out:
# C:\Users\CLASSISH\AppData\Local\Temp/ipykernel_5048/3504866275.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Engagement_labels'] = kmeans.labels_

# %%
X
# Out:
#         Session frequency  Dur. (ms)  Total_volume (Bytes)  Engagement_labels
# 0                       1   0.055330             -0.984474                  2
# 1                       1   0.055330              1.938198                  0
# 2                       1   0.055330             -1.889650                  2
# 3                       1   0.055330              1.798275                  0
# 4                       1   0.055330              0.240365                  1
# ...                   ...        ...                   ...                ...
# 148501                  1  -0.561190              0.140811                  1
# 148502                  1  -0.294231              1.953256                  0
# 148503                  1  -0.087749              0.692219                  1
# 148504                  2  -0.084308              0.015305                  1
# 148505                  2  -0.088489             -1.358018                  2
#
# [148506 rows x 4 columns]

# %%
X.describe()
# Out:
#        Session frequency      Dur. (ms)  Total_volume (Bytes)  \
# count      148506.000000  148506.000000          1.485060e+05
# mean            1.240327      -0.090620          7.218246e-03
# std             0.638478       0.561425          1.090028e+00
# min             1.000000      -1.047212         -2.323021e+00
# 25%             1.000000      -0.380642         -7.785400e-01
# 50%             1.000000      -0.230461         -1.374139e-16
# 75%             1.000000       0.143047          7.823430e-01
# max            16.000000       1.688674          2.322077e+00
#
#        Engagement_labels
# count      148506.000000
# mean            1.011090
# std             0.739114
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             2.000000
# max             2.000000

# %%
X1 = X[X.Engagement_labels==1]
X0 = X[X.Engagement_labels==0]
X2 = X[X.Engagement_labels==2]

# %% [markdown]
# Fetch columns for experience metrics

# %%
needed_cols = ['Avg RTT DL (ms)','Avg RTT UL (ms)','Avg Bearer TP DL (kbps)','Avg Bearer TP UL (kbps)','TCP DL Retrans. Vol (Bytes)','TCP UL Retrans. Vol (Bytes)']

# %%
df.describe()
# Out:
#               index     Bearer Id      Start ms        End ms      Dur. (ms)  \
# count  1.485060e+05  1.485060e+05  1.485060e+05  1.485060e+05  148506.000000
# mean   6.124296e-17 -4.561644e-16  7.657762e-17 -4.475999e-17      -0.090620
# std    1.000003e+00  1.000003e+00  1.000003e+00  1.000003e+00       0.561425
# min   -1.736517e+00 -1.116121e+00 -1.729974e+00 -1.730974e+00      -1.047212
# 25%   -8.630556e-01 -9.666889e-01 -8.636097e-01 -8.596554e-01      -0.380642
# 50%   -2.094556e-03 -9.666889e-01 -7.109151e-04  4.720407e-03      -0.230461
# 75%    8.673002e-01  1.000835e+00  8.656534e-01  8.690962e-01       0.143047
# max    1.729370e+00  1.050646e+00  1.732018e+00  1.736943e+00       1.688674
#
#                IMSI  MSISDN/Number          IMEI  Avg RTT DL (ms)  \
# count  1.485060e+05   1.485060e+05  1.485060e+05    148506.000000
# mean  -1.247852e-12  -1.525093e-19  3.487021e-16        -0.067472
# std    1.000003e+00   1.000003e+00  1.000003e+00         0.070952
# min   -2.725432e+02  -3.388678e-03 -2.142496e+00        -0.157090
# 25%   -1.303239e-02  -3.368152e-03 -5.813090e-01        -0.130656
# 50%   -3.515589e-03  -3.363094e-03 -5.696471e-01        -0.089118
# 75%    1.126367e-02  -3.355012e-03  1.677018e+00         0.000000
# max    3.317321e+00   3.600028e+02  2.251262e+00         0.214866
#
#        Avg RTT UL (ms)  ...  Gaming UL (Bytes)  Other DL (Bytes)  \
# count    148506.000000  ...       1.485060e+05      1.485060e+05
# mean         -0.080535  ...      -2.062165e-17      4.265476e-17
# std           0.119756  ...       1.000003e+00      1.000003e+00
# min          -0.217451  ...      -1.733506e+00     -1.731962e+00
# 25%          -0.178220  ...      -8.697119e-01     -8.671063e-01
# 50%          -0.112833  ...       4.286774e-04      2.916946e-03
# 75%           0.000000  ...       8.663118e-01      8.655972e-01
# max           0.344870  ...       1.729251e+00      1.736653e+00
#
#        Other UL (Bytes)  Total UL (Bytes)  Total DL (Bytes)  \
# count      1.485060e+05      1.485060e+05      1.485060e+05
# mean       7.827616e-17     -2.451632e-16      1.090890e-16
# std        1.000003e+00      1.000003e+00      1.000003e+00
# min       -1.732628e+00     -3.391657e+00     -1.832882e+00
# 25%       -8.636376e-01     -7.005508e-01     -8.663250e-01
# 50%        6.984898e-04      2.002651e-03      5.228838e-03
# 75%        8.634914e-01      7.016198e-01      8.644919e-01
# max        1.739672e+00      3.299398e+00      1.835977e+00
#
#        Total_volume (Bytes)  Session frequency  AVG RTT (ms)  \
# count          1.485060e+05      148506.000000  1.485060e+05
# mean           7.218246e-03           1.240327  2.234411e-17
# std            1.090028e+00           0.638478  1.419633e+00
# min           -2.323021e+00           1.000000 -4.310445e-01
# 25%           -7.785400e-01           1.000000 -3.090154e-01
# 50%           -1.374139e-16           1.000000 -2.041186e-01
# 75%            7.823430e-01           1.000000  0.000000e+00
# max            2.322077e+00          16.000000  1.825823e+02
#
#        Avg Bearer TP (kbps)  TCP Retrans. Vol (Bytes)
# count          1.485060e+05              1.485060e+05
# mean          -5.081252e-17             -6.741510e-17
# std            1.765438e+00              1.420845e+00
# min           -9.361938e-01             -2.279397e-01
# 25%           -9.242018e-01             -1.793037e-01
# 50%           -9.200605e-01             -6.359696e-17
# 75%            3.015852e-01             -6.359696e-17
# max            2.100730e+01              1.832445e+02
#
# [8 rows x 56 columns]

# %% [markdown]
# Store Experience Metrics in Y dataframe

# %%
Y = df[['AVG RTT (ms)','Avg Bearer TP (kbps)','TCP Retrans. Vol (Bytes)']]

# %%
Y
# Out:
#         AVG RTT (ms)  Avg Bearer TP (kbps)  TCP Retrans. Vol (Bytes)
# 0          -0.286358             -0.925733             -6.359696e-17
# 1          -0.242932             -0.929912             -6.359696e-17
# 2           0.000000             -0.934000             -6.359696e-17
# 3           0.000000             -0.924857             -6.359696e-17
# 4           0.000000             -0.934000             -6.359696e-17
# ...              ...                   ...                       ...
# 148501      0.277626              2.007879             -7.639381e-02
# 148502     -0.370625             -0.919989             -6.359696e-17
# 148503     -0.353911             -0.923573             -6.359696e-17
# 148504     -0.271393             -0.924251             -6.359696e-17
# 148505     -0.295799             -0.926786             -6.359696e-17
#
# [148506 rows x 3 columns]

# %% [markdown]
# Use of Kmeans to seperate Experience metrics to 3 clusters

# %%
kmeans.fit(Y)
# Out:
# KMeans(init='random', n_clusters=3, random_state=42)

# %%
Y['Experience_labels'] = kmeans.labels_
# Out:
# C:\Users\CLASSISH\AppData\Local\Temp/ipykernel_5048/1125441398.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y['Experience_labels'] = kmeans.labels_

# %%
Y['Experience_labels'].value_counts()
# Out:
# 0    127683
# 2     20112
# 1       711
# Name: Experience_labels, dtype: int64

# %%
Y1 = Y[Y.Experience_labels==1]
Y0 = Y[Y.Experience_labels==0]
Y2 = Y[Y.Experience_labels==2]

# %% [markdown]
# ## Task 4.1

# %% [markdown]
# Get the euclidean distance between the engagement metrics and the least engagement label to get Engagement score

# %%
X['Engagement_score'] =np.sqrt(((X2['Session frequency'] + X['Dur. (ms)'] + X['Total_volume (Bytes)']).pow(2)) - ((2**2)))
X['Engagement_score'] = X['Engagement_score'].fillna(0)
# Out:
# C:\Users\CLASSISH\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\CLASSISH\AppData\Local\Temp/ipykernel_5048/2325902614.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Engagement_score'] =np.sqrt(((X2['Session frequency'] + X['Dur. (ms)'] + X['Total_volume (Bytes)']).pow(2)) - ((2**2)))
# C:\Users\CLASSISH\AppData\Local\Temp/ipykernel_5048/2325902614.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Engagement_score'] = X['Engagement_score'].fillna(0)

# %%
X['Engagement_score'].value_counts()
# Out:
# 0.000000    147335
# 0.580058         1
# 0.299444         1
# 0.652856         1
# 0.724395         1
#              ...
# 4.599944         1
# 4.772829         1
# 4.030307         1
# 0.907907         1
# 1.669558         1
# Name: Engagement_score, Length: 1172, dtype: int64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148506 entries, 0 to 148505
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Session frequency     148506 non-null  int64
#  1   Dur. (ms)             148506 non-null  float64
#  2   Total_volume (Bytes)  148506 non-null  float64
#  3   Engagement_labels     148506 non-null  int32
#  4   Engagement_score      148506 non-null  float64
# dtypes: float64(3), int32(1), int64(1)
# memory usage: 5.1 MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148506 entries, 0 to 148505
# Data columns (total 61 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   index                                     148506 non-null  float64
#  1   Bearer Id                                 148506 non-null  float64
#  2   Start                                     148506 non-null  object
#  3   Start ms                                  148506 non-null  float64
#  4   End                                       148506 non-null  object
#  5   End ms                                    148506 non-null  float64
#  6   Dur. (ms)                                 148506 non-null  float64
#  7   IMSI                                      148506 non-null  float64
#  8   MSISDN/Number                             148506 non-null  float64
#  9   IMEI                                      148506 non-null  float64
#  10  Last Location Name                        148506 non-null  object
#  11  Avg RTT DL (ms)                           148506 non-null  float64
#  12  Avg RTT UL (ms)                           148506 non-null  float64
#  13  Avg Bearer TP DL (kbps)                   148506 non-null  float64
#  14  Avg Bearer TP UL (kbps)                   148506 non-null  float64
#  15  TCP DL Retrans. Vol (Bytes)               148506 non-null  float64
#  16  TCP UL Retrans. Vol (Bytes)               148506 non-null  float64
#  17  DL TP < 50 Kbps (%)                       148506 non-null  float64
#  18  50 Kbps < DL TP < 250 Kbps (%)            148506 non-null  float64
#  19  250 Kbps < DL TP < 1 Mbps (%)             148506 non-null  float64
#  20  DL TP > 1 Mbps (%)                        148506 non-null  float64
#  21  UL TP < 10 Kbps (%)                       148506 non-null  float64
#  22  10 Kbps < UL TP < 50 Kbps (%)             148506 non-null  float64
#  23  50 Kbps < UL TP < 300 Kbps (%)            148506 non-null  float64
#  24  UL TP > 300 Kbps (%)                      148506 non-null  float64
#  25  HTTP DL (Bytes)                           148506 non-null  float64
#  26  HTTP UL (Bytes)                           148506 non-null  float64
#  27  Activity Duration DL (ms)                 148506 non-null  float64
#  28  Activity Duration UL (ms)                 148506 non-null  float64
#  29  Dur. (ms).1                               148506 non-null  float64
#  30  Handset Manufacturer                      148506 non-null  object
#  31  Handset Type                              148506 non-null  object
#  32  Nb of sec with 125000B < Vol DL           148506 non-null  float64
#  33  Nb of sec with 1250B < Vol UL < 6250B     148506 non-null  float64
#  34  Nb of sec with 31250B < Vol DL < 125000B  148506 non-null  float64
#  35  Nb of sec with 37500B < Vol UL            148506 non-null  float64
#  36  Nb of sec with 6250B < Vol DL < 31250B    148506 non-null  float64
#  37  Nb of sec with 6250B < Vol UL < 37500B    148506 non-null  float64
#  38  Nb of sec with Vol DL < 6250B             148506 non-null  float64
#  39  Nb of sec with Vol UL < 1250B             148506 non-null  float64
#  40  Social Media DL (Bytes)                   148506 non-null  float64
#  41  Social Media UL (Bytes)                   148506 non-null  float64
#  42  Google DL (Bytes)                         148506 non-null  float64
#  43  Google UL (Bytes)                         148506 non-null  float64
#  44  Email DL (Bytes)                          148506 non-null  float64
#  45  Email UL (Bytes)                          148506 non-null  float64
#  46  Youtube DL (Bytes)                        148506 non-null  float64
#  47  Youtube UL (Bytes)                        148506 non-null  float64
#  48  Netflix DL (Bytes)                        148506 non-null  float64
#  49  Netflix UL (Bytes)                        148506 non-null  float64
#  50  Gaming DL (Bytes)                         148506 non-null  float64
#  51  Gaming UL (Bytes)                         148506 non-null  float64
#  52  Other DL (Bytes)                          148506 non-null  float64
#  53  Other UL (Bytes)                          148506 non-null  float64
#  54  Total UL (Bytes)                          148506 non-null  float64
#  55  Total DL (Bytes)                          148506 non-null  float64
#  56  Total_volume (Bytes)                      148506 non-null  float64
#  57  Session frequency                         148506 non-null  int64
#  58  AVG RTT (ms)                              148506 non-null  float64
#  59  Avg Bearer TP (kbps)                      148506 non-null  float64
#  60  TCP Retrans. Vol (Bytes)                  148506 non-null  float64
# dtypes: float64(55), int64(1), object(5)
# memory usage: 69.1+ MB

# %%
Y['Experience_labels'].value_counts()
# Out:
# 0    127683
# 2     20112
# 1       711
# Name: Experience_labels, dtype: int64

# %% [markdown]
# Get the euclidean distance between the Experience metrics and the least engagement label to get Experience score

# %%
Y['Experience_score'] =np.sqrt(((Y2['AVG RTT (ms)'] + Y2['Avg Bearer TP (kbps)'] + Y2['TCP Retrans. Vol (Bytes)']).pow(2)) - ((2**2)))
Y['Experience_score'] = Y['Experience_score'].fillna(0)
# Out:
# C:\Users\CLASSISH\AppData\Local\Temp/ipykernel_5048/158759607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y['Experience_score'] =np.sqrt(((Y2['AVG RTT (ms)'] + Y2['Avg Bearer TP (kbps)'] + Y2['TCP Retrans. Vol (Bytes)']).pow(2)) - ((2**2)))
# C:\Users\CLASSISH\AppData\Local\Temp/ipykernel_5048/158759607.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y['Experience_score'] = Y['Experience_score'].fillna(0)

# %%
Y
# Out:
#         AVG RTT (ms)  Avg Bearer TP (kbps)  TCP Retrans. Vol (Bytes)  \
# 0          -0.286358             -0.925733             -6.359696e-17
# 1          -0.242932             -0.929912             -6.359696e-17
# 2           0.000000             -0.934000             -6.359696e-17
# 3           0.000000             -0.924857             -6.359696e-17
# 4           0.000000             -0.934000             -6.359696e-17
# ...              ...                   ...                       ...
# 148501      0.277626              2.007879             -7.639381e-02
# 148502     -0.370625             -0.919989             -6.359696e-17
# 148503     -0.353911             -0.923573             -6.359696e-17
# 148504     -0.271393             -0.924251             -6.359696e-17
# 148505     -0.295799             -0.926786             -6.359696e-17
#
#         Experience_labels  Experience_score
# 0                       0          0.000000
# 1                       0          0.000000
# 2                       0          0.000000
# 3                       0          0.000000
# 4                       0          0.000000
# ...                   ...               ...
# 148501                  2          0.938173
# 148502                  0          0.000000
# 148503                  0          0.000000
# 148504                  0          0.000000
# 148505                  0          0.000000
#
# [148506 rows x 5 columns]

# %%
Y['Experience_score'].value_counts()
# Out:
# 0.000000    133446
# 2.883482         1
# 7.407336         1
# 2.126804         1
# 2.451135         1
#              ...
# 1.284306         1
# 3.056484         1
# 0.352108         1
# 3.582946         1
# 0.938173         1
# Name: Experience_score, Length: 15061, dtype: int64

# %%
new_df= pd.DataFrame()

# %%
new_df['MSISDN/Number'] = df['MSISDN/Number']

# %%
new_df = new_df.join(X)
new_df = new_df.join(Y)

# %%
new_df['Experience_score'].value_counts()
# Out:
# 0.000000    133446
# 2.883482         1
# 7.407336         1
# 2.126804         1
# 2.451135         1
#              ...
# 1.284306         1
# 3.056484         1
# 0.352108         1
# 3.582946         1
# 0.938173         1
# Name: Experience_score, Length: 15061, dtype: int64

# %% [markdown]
# ## Task 4.2

# %% [markdown]
# Get the Satisfaction score from the average of engagement and experience score.

# %%
new_df['Satisfaction_score'] = ((new_df['Engagement_score'] + new_df['Experience_score'])/2)+1
new_df['Satisfaction_score'] = new_df['Satisfaction_score'].fillna(0)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148506 entries, 0 to 148505
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   MSISDN/Number             148506 non-null  float64
#  1   Session frequency         148506 non-null  int64
#  2   Dur. (ms)                 148506 non-null  float64
#  3   Total_volume (Bytes)      148506 non-null  float64
#  4   Engagement_labels         148506 non-null  int32
#  5   Engagement_score          148506 non-null  float64
#  6   AVG RTT (ms)              148506 non-null  float64
#  7   Avg Bearer TP (kbps)      148506 non-null  float64
#  8   TCP Retrans. Vol (Bytes)  148506 non-null  float64
#  9   Experience_labels         148506 non-null  int32
#  10  Experience_score          148506 non-null  float64
#  11  Satisfaction_score        148506 non-null  float64
# dtypes: float64(9), int32(2), int64(1)
# memory usage: 12.5 MB

# %%
new_df.head(50)
# Out:
#     MSISDN/Number  Session frequency  Dur. (ms)  Total_volume (Bytes)  \
# 0       -0.003363                  1    0.05533         -9.844744e-01
# 1       -0.003356                  1    0.05533          1.938198e+00
# 2       -0.003324                  1    0.05533         -1.889650e+00
# 3       -0.003328                  1    0.05533          1.798275e+00
# 4       -0.003348                  1    0.05533          2.403649e-01
# 5       -0.003361                  1    0.05533          2.691306e-01
# 6       -0.003362                  1    0.05533         -9.695963e-01
# 7       -0.003322                  1    0.05533          1.408111e-01
# 8       -0.003349                  1    0.05533          1.776882e+00
# 9       -0.003365                  1    0.05533         -3.677768e-02
# 10      -0.003362                  1    0.05533          1.943594e+00
# 11      -0.003363                  1    0.05533         -3.290826e-01
# 12      -0.003388                  1    0.05533          1.321806e+00
# 13      -0.003365                  1    0.05533          1.132276e+00
# 14      -0.003365                  1    0.05533         -1.404858e+00
# 15      -0.003326                  1    0.05533         -1.562507e-01
# 16      -0.003361                  1    0.05533         -7.783625e-01
# 17      -0.003361                  1    0.05533         -1.052669e+00
# 18      -0.003349                  1    0.05533         -5.924440e-01
# 19      -0.003324                  1    0.05533          6.759781e-01
# 20      -0.003365                  2    0.05533         -1.470356e+00
# 21      -0.003365                  1    0.05533          1.663694e-01
# 22      -0.003380                  1    0.05533          1.092839e+00
# 23      -0.003356                  1    0.05533          1.881310e+00
# 24      -0.003384                  1    0.05533          1.408111e-01
# 25      -0.003320                  1    0.05533         -7.142791e-01
# 26      -0.003363                  1    0.05533         -1.085903e+00
# 27      -0.003363                  1    0.05533         -5.734953e-01
# 28      -0.003361                  1    0.05533         -1.253694e+00
# 29      -0.003349                  1    0.05533          4.149714e-04
# 30      -0.003365                  2    0.05533          9.522194e-01
# 31      -0.003388                  1    0.05533         -6.281335e-01
# 32      -0.003349                  1    0.05533          1.906531e+00
# 33      -0.003365                  1    0.05533          9.658673e-01
# 34      -0.003324                  1    0.05533          1.408111e-01
# 35      -0.003363                  1    0.05533         -1.374139e-16
# 36      -0.003364                  1    0.05533          7.548495e-01
# 37      -0.003364                  1    0.05533         -1.519921e+00
# 38      -0.003322                  1    0.05533         -2.489647e-03
# 39      -0.003361                  1    0.05533         -1.965537e-01
# 40      -0.003356                  1    0.05533         -1.079631e+00
# 41      -0.003323                  1    0.05533         -1.124044e-01
# 42      -0.003362                  1    0.05533          1.354068e-01
# 43      -0.003322                  5    0.05533         -7.399991e-01
# 44      -0.003368                  1    0.05533         -4.222653e-01
# 45      -0.003361                  1    0.05533         -1.205524e+00
# 46      -0.003362                  1    0.05533         -1.183095e+00
# 47      -0.003362                  1    0.05533         -1.414136e+00
# 48      -0.003369                  1    0.05533          4.668709e-01
# 49      -0.003324                  1    0.05533          1.645417e+00
#
#     Engagement_labels  Engagement_score  AVG RTT (ms)  Avg Bearer TP (kbps)  \
# 0                   2          0.000000     -0.286358             -0.925733
# 1                   0          0.000000     -0.242932             -0.929912
# 2                   2          0.000000      0.000000             -0.934000
# 3                   0          0.000000      0.000000             -0.924857
# 4                   1          0.000000      0.000000             -0.934000
# 5                   1          0.000000      0.000000             -0.921614
# 6                   2          0.000000     -0.173072             -0.927070
# 7                   1          0.000000     -0.122019             -0.692225
# 8                   0          0.000000      0.000000             -0.923694
# 9                   1          0.000000     -0.156358             -0.228460
# 10                  0          0.000000      0.000000             -0.934000
# 11                  1          0.000000      0.030982              1.647305
# 12                  0          0.000000      0.000000             -0.921989
# 13                  0          0.000000      0.000000             -0.935762
# 14                  2          0.000000     -0.229576              0.217187
# 15                  1          0.000000      0.074140             -0.791332
# 16                  2          0.000000     -0.370904             -0.917173
# 17                  2          0.000000     -0.297687             -0.929912
# 18                  1          0.000000     -0.258037             -0.923671
# 19                  1          0.000000      0.000000             -0.934000
# 20                  2          0.000000      0.903509              2.573339
# 21                  1          0.000000     -0.233631             -0.337335
# 22                  0          0.000000     -0.376429             -0.922921
# 23                  0          0.000000      0.000000             -0.933784
# 24                  1          0.000000      0.000000             -0.921872
# 25                  2          0.000000     -0.259785             -0.927718
# 26                  2          0.000000     -0.290274             -0.925232
# 27                  1          0.000000      0.000000             -0.934000
# 28                  2          0.000000     -0.351884             -0.930461
# 29                  1          0.000000      0.343516             -0.138429
# 30                  0          0.000000      0.372106              1.705038
# 31                  1          0.000000      0.000000             -0.923095
# 32                  0          0.000000     -0.382233             -0.922823
# 33                  0          0.000000      0.000000             -0.922489
# 34                  1          0.000000     -0.357548             -0.927070
# 35                  1          0.000000      0.000000             -0.934000
# 36                  0          0.000000     -0.314680             -0.929953
# 37                  2          0.000000      0.000000             -0.934000
# 38                  1          0.000000     -0.255730             -0.897376
# 39                  1          0.000000     -0.097892             -0.934080
# 40                  2          0.000000      0.000000             -0.922698
# 41                  1          0.000000     -0.349996             -0.923671
# 42                  1          0.000000      0.000000             -0.934000
# 43                  2          3.823883     -0.015373              0.303511
# 44                  1          0.000000      0.000000             -0.934000
# 45                  2          0.000000     -0.342443             -0.933053
# 46                  2          0.000000      0.131201              0.739533
# 47                  2          0.000000     -0.346220             -0.914726
# 48                  1          0.000000     -0.290274             -0.923569
# 49                  0          0.000000      0.000000             -0.934000
#
#     TCP Retrans. Vol (Bytes)  Experience_labels  Experience_score  \
# 0              -6.359696e-17                  0          0.000000
# 1              -6.359696e-17                  0          0.000000
# 2              -6.359696e-17                  0          0.000000
# 3              -6.359696e-17                  0          0.000000
# 4              -6.359696e-17                  0          0.000000
# 5              -6.359696e-17                  0          0.000000
# 6              -6.359696e-17                  0          0.000000
# 7              -1.791441e-01                  0          0.000000
# 8              -6.359696e-17                  0          0.000000
# 9              -1.999040e-01                  0          0.000000
# 10             -6.359696e-17                  0          0.000000
# 11             -1.594163e-01                  2          0.000000
# 12             -6.359696e-17                  0          0.000000
# 13             -6.359696e-17                  0          0.000000
# 14              5.382938e-02                  0          0.000000
# 15             -6.163427e-02                  0          0.000000
# 16             -6.359696e-17                  0          0.000000
# 17             -6.359696e-17                  0          0.000000
# 18             -6.359696e-17                  0          0.000000
# 19             -6.359696e-17                  0          0.000000
# 20             -1.425544e-01                  2          2.667868
# 21             -1.524884e-02                  0          0.000000
# 22             -6.359696e-17                  0          0.000000
# 23             -6.359696e-17                  0          0.000000
# 24             -6.359696e-17                  0          0.000000
# 25             -6.359696e-17                  0          0.000000
# 26             -6.359696e-17                  0          0.000000
# 27             -6.359696e-17                  0          0.000000
# 28             -6.359696e-17                  0          0.000000
# 29             -6.359696e-17                  0          0.000000
# 30             -6.711363e-02                  2          0.200549
# 31             -6.359696e-17                  0          0.000000
# 32             -6.359696e-17                  0          0.000000
# 33             -6.359696e-17                  0          0.000000
# 34             -6.359696e-17                  0          0.000000
# 35             -6.359696e-17                  0          0.000000
# 36             -6.359696e-17                  0          0.000000
# 37             -6.359696e-17                  0          0.000000
# 38             -2.009032e-01                  0          0.000000
# 39             -6.359696e-17                  0          0.000000
# 40             -6.359696e-17                  0          0.000000
# 41             -6.359696e-17                  0          0.000000
# 42             -6.359696e-17                  0          0.000000
# 43             -2.249830e-01                  0          0.000000
# 44             -6.359696e-17                  0          0.000000
# 45             -6.359696e-17                  0          0.000000
# 46             -2.025318e-01                  0          0.000000
# 47             -6.359696e-17                  0          0.000000
# 48             -6.359696e-17                  0          0.000000
# 49             -6.359696e-17                  0          0.000000
#
#     Satisfaction_score
# 0             1.000000
# 1             1.000000
# 2             1.000000
# 3             1.000000
# 4             1.000000
# 5             1.000000
# 6             1.000000
# 7             1.000000
# 8             1.000000
# 9             1.000000
# 10            1.000000
# 11            1.000000
# 12            1.000000
# 13            1.000000
# 14            1.000000
# 15            1.000000
# 16            1.000000
# 17            1.000000
# 18            1.000000
# 19            1.000000
# 20            2.333934
# 21            1.000000
# 22            1.000000
# 23            1.000000
# 24            1.000000
# 25            1.000000
# 26            1.000000
# 27            1.000000
# 28            1.000000
# 29            1.000000
# 30            1.100275
# 31            1.000000
# 32            1.000000
# 33            1.000000
# 34            1.000000
# 35            1.000000
# 36            1.000000
# 37            1.000000
# 38            1.000000
# 39            1.000000
# 40            1.000000
# 41            1.000000
# 42            1.000000
# 43            2.911942
# 44            1.000000
# 45            1.000000
# 46            1.000000
# 47            1.000000
# 48            1.000000
# 49            1.000000

# %%
new_df['Satisfaction_score'].sort_values(ascending=False)[:10]
# Out:
# 1817      14.467387
# 146874    13.354777
# 37649     12.196516
# 57811     11.746603
# 67629     11.630514
# 90258     11.380157
# 36204     11.056983
# 77197     11.035598
# 64973     10.802204
# 79053     10.780743
# Name: Satisfaction_score, dtype: float64

# %%
new_df.sort_values(ascending=False, by='Satisfaction_score')[:10]
# Out:
#         MSISDN/Number  Session frequency  Dur. (ms)  Total_volume (Bytes)  \
# 1817        -0.003363                  1  -0.230473          1.474995e+00
# 146874      -0.003323                 16  -0.230473         -9.436103e-01
# 37649       -0.003362                  4  -0.230473         -8.082499e-01
# 57811       -0.003323                  1  -0.230461         -6.511287e-01
# 67629       -0.003323                  1  -0.230461          2.126456e-01
# 90258       -0.003362                  1  -0.713202         -1.374139e-16
# 36204       -0.003364                  2  -0.230473         -1.224055e+00
# 77197       -0.003322                  2  -0.206779          6.695080e-01
# 64973       -0.003361                  4  -0.230461          1.391034e+00
# 79053       -0.003349                  1  -0.443875         -1.374139e-16
#
#         Engagement_labels  Engagement_score  AVG RTT (ms)  \
# 1817                    0          0.000000      1.630599
# 146874                  2         14.690398      0.203721
# 37649                   2          2.183840      0.329666
# 57811                   1          0.000000      0.253928
# 67629                   1          0.000000      0.269730
# 90258                   1          0.000000     -0.151810
# 36204                   2          0.000000      2.545801
# 77197                   1          0.000000      0.424629
# 64973                   0          0.000000     -0.035724
# 79053                   1          0.000000      0.857583
#
#         Avg Bearer TP (kbps)  TCP Retrans. Vol (Bytes)  Experience_labels  \
# 1817               13.155008                 12.223320                  2
# 146874              9.775711                  0.237392                  2
# 37649               7.372795                 12.605453                  2
# 57811               7.885140                 13.446991                  2
# 67629               7.969450                 13.115709                  2
# 90258              21.007296                  0.000943                  2
# 36204              13.188554                  4.478800                  2
# 77197               7.938475                 11.807491                  2
# 64973               6.352619                 13.389267                  2
# 79053               6.370326                 12.435554                  2
#
#         Experience_score  Satisfaction_score
# 1817           26.934775           14.467387
# 146874         10.019157           13.354777
# 37649          20.209191           12.196516
# 57811          21.493207           11.746603
# 67629          21.261028           11.630514
# 90258          20.760314           11.380157
# 36204          20.113965           11.056983
# 77197          20.071196           11.035598
# 64973          19.604408           10.802204
# 79053          19.561486           10.780743

# %% [markdown]
# ## Task 4.3

# %% [markdown]
# Build a regression model to predict the satisfaction score from the engagement and experience numerical metrics.

# %%
y = new_df['Satisfaction_score']

# %%
cols_drop = ['MSISDN/Number','Satisfaction_score','Engagement_labels','Experience_labels','Experience_score','Engagement_score']
X = new_df.drop(cols_drop,axis=1)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148506 entries, 0 to 148505
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Session frequency         148506 non-null  int64
#  1   Dur. (ms)                 148506 non-null  float64
#  2   Total_volume (Bytes)      148506 non-null  float64
#  3   AVG RTT (ms)              148506 non-null  float64
#  4   Avg Bearer TP (kbps)      148506 non-null  float64
#  5   TCP Retrans. Vol (Bytes)  148506 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 6.8 MB

# %%
y.value_counts()
# Out:
# 1.000000    132412
# 2.046624         1
# 1.890958         1
# 2.272980         1
# 1.519368         1
#              ...
# 1.875804         1
# 3.960809         1
# 3.221544         1
# 2.360387         1
# 1.469087         1
# Name: Satisfaction_score, Length: 16095, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42, test_size= 0.25)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (111379, 6)
# (37127, 6)
# (111379,)
# (37127,)

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(X_train,y_train)
print(lin_reg.intercept_)
print(lin_reg.coef_)
# Out:
# 1.1683583751524635
# [ 0.03017033  0.11021657 -0.00684285  0.0071424   0.34898573  0.00499308]

# %% [markdown]
# Evaluate the model built

# %%
model = lin_reg.predict(X_test)

# %%
print(f"Root mean squared error {np.sqrt(mean_squared_error(y_test,model))}")
print(f"Mean squared error {mean_squared_error(y_test,model)}")
print(f"Mean Absolute error {mean_absolute_error(y_test,model)}")
# Out:
# Root mean squared error 0.37531103971228874
# Mean squared error 0.14085837652991917
# Mean Absolute error 0.22366972466250032

# %%
score_check = pd.DataFrame()

# %%
score_check['y_test'] = y_test

# %%
score_check['model'] = model

# %%
score_check
# Out:
#           y_test     model
# 63312   1.000000  0.860135
# 32540   1.000000  0.920415
# 32971   1.000000  0.892716
# 6396    1.000000  1.120522
# 43350   1.000000  0.907441
# ...          ...       ...
# 136000  1.000000  0.982461
# 139153  1.000000  0.881651
# 29881   1.000000  0.962632
# 59861   2.870834  2.612562
# 33507   1.000000  0.884277
#
# [37127 rows x 2 columns]

# %% [markdown]
# ## Task 4.4

# %% [markdown]
# Run a Kmeans to seperate engagement and experience score to two clusters

# %%
metrics = new_df[['Engagement_score','Experience_score']]

# %%
met_cols = ['Engagement_score','Experience_score']

# %%
Kmeans_2 = KMeans(
    init= "random",
    n_clusters = 2,
    n_init= 10,
    max_iter= 300,
    random_state= 42
)

# %%
Kmeans_2.fit(metrics)
# Out:
# KMeans(init='random', n_clusters=2, random_state=42)

# %%
metrics
# Out:
#         Engagement_score  Experience_score
# 0                    0.0          0.000000
# 1                    0.0          0.000000
# 2                    0.0          0.000000
# 3                    0.0          0.000000
# 4                    0.0          0.000000
# ...                  ...               ...
# 148501               0.0          0.938173
# 148502               0.0          0.000000
# 148503               0.0          0.000000
# 148504               0.0          0.000000
# 148505               0.0          0.000000
#
# [148506 rows x 2 columns]

# %%
metrics['cluster'] = Kmeans_2.labels_
# Out:
# C:\Users\CLASSISH\AppData\Local\Temp/ipykernel_5048/2972770247.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['cluster'] = Kmeans_2.labels_

# %% [markdown]
# ## Task 4.5

# %%
metrics['Satisfaction_score'] = new_df['Satisfaction_score']
# Out:
# C:\Users\CLASSISH\AppData\Local\Temp/ipykernel_5048/3150825679.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Satisfaction_score'] = new_df['Satisfaction_score']

# %% [markdown]
# Aggregate the average satisfaction and experience score per cluster

# %%
satisfied_per_cluster = metrics.groupby('cluster').agg({'Satisfaction_score':["median","mean"]})

# %%
satisfied_per_cluster
# Out:
#         Satisfaction_score
#                     median      mean
# cluster
# 0                 1.000000  1.044561
# 1                 3.323308  3.705349

# %%
experience_per_cluster = metrics.groupby('cluster').agg({'Experience_score':["median","mean"]})

# %%
experience_per_cluster
# Out:
#         Experience_score
#                   median      mean
# cluster
# 0                0.00000  0.076590
# 1                4.62993  5.389693

# %%
new_df
# Out:
#         MSISDN/Number  Session frequency  Dur. (ms)  Total_volume (Bytes)  \
# 0           -0.003363                  1   0.055330             -0.984474
# 1           -0.003356                  1   0.055330              1.938198
# 2           -0.003324                  1   0.055330             -1.889650
# 3           -0.003328                  1   0.055330              1.798275
# 4           -0.003348                  1   0.055330              0.240365
# ...               ...                ...        ...                   ...
# 148501      -0.003361                  1  -0.561190              0.140811
# 148502      -0.003368                  1  -0.294231              1.953256
# 148503      -0.003363                  1  -0.087749              0.692219
# 148504      -0.003380                  2  -0.084308              0.015305
# 148505      -0.003381                  2  -0.088489             -1.358018
#
#         Engagement_labels  Engagement_score  AVG RTT (ms)  \
# 0                       2               0.0     -0.286358
# 1                       0               0.0     -0.242932
# 2                       2               0.0      0.000000
# 3                       0               0.0      0.000000
# 4                       1               0.0      0.000000
# ...                   ...               ...           ...
# 148501                  1               0.0      0.277626
# 148502                  0               0.0     -0.370625
# 148503                  1               0.0     -0.353911
# 148504                  1               0.0     -0.271393
# 148505                  2               0.0     -0.295799
#
#         Avg Bearer TP (kbps)  TCP Retrans. Vol (Bytes)  Experience_labels  \
# 0                  -0.925733             -6.359696e-17                  0
# 1                  -0.929912             -6.359696e-17                  0
# 2                  -0.934000             -6.359696e-17                  0
# 3                  -0.924857             -6.359696e-17                  0
# 4                  -0.934000             -6.359696e-17                  0
# ...                      ...                       ...                ...
# 148501              2.007879             -7.639381e-02                  2
# 148502             -0.919989             -6.359696e-17                  0
# 148503             -0.923573             -6.359696e-17                  0
# 148504             -0.924251             -6.359696e-17                  0
# 148505             -0.926786             -6.359696e-17                  0
#
#         Experience_score  Satisfaction_score
# 0               0.000000            1.000000
# 1               0.000000            1.000000
# 2               0.000000            1.000000
# 3               0.000000            1.000000
# 4               0.000000            1.000000
# ...                  ...                 ...
# 148501          0.938173            1.469087
# 148502          0.000000            1.000000
# 148503          0.000000            1.000000
# 148504          0.000000            1.000000
# 148505          0.000000            1.000000
#
# [148506 rows x 12 columns]

# %%
metrics
# Out:
#         Engagement_score  Experience_score  cluster  Satisfaction_score
# 0                    0.0          0.000000        0            1.000000
# 1                    0.0          0.000000        0            1.000000
# 2                    0.0          0.000000        0            1.000000
# 3                    0.0          0.000000        0            1.000000
# 4                    0.0          0.000000        0            1.000000
# ...                  ...               ...      ...                 ...
# 148501               0.0          0.938173        0            1.469087
# 148502               0.0          0.000000        0            1.000000
# 148503               0.0          0.000000        0            1.000000
# 148504               0.0          0.000000        0            1.000000
# 148505               0.0          0.000000        0            1.000000
#
# [148506 rows x 4 columns]

# %% [markdown]
# ## Task 4.6

# %% [markdown]
# Export final table to SQL database

# %%
sql_df = pd.DataFrame()

# %%
sql_df['MSISDN/Number'] = new_df['MSISDN/Number']

# %%
cols_sql_df = ['Engagement_score','Experience_score','Satisfaction_score']
sql_df[cols_sql_df] = metrics[cols_sql_df]

# %%
sql_df
# Out:
#         MSISDN/Number  Engagement_score  Experience_score  Satisfaction_score
# 0           -0.003363               0.0          0.000000            1.000000
# 1           -0.003356               0.0          0.000000            1.000000
# 2           -0.003324               0.0          0.000000            1.000000
# 3           -0.003328               0.0          0.000000            1.000000
# 4           -0.003348               0.0          0.000000            1.000000
# ...               ...               ...               ...                 ...
# 148501      -0.003361               0.0          0.938173            1.469087
# 148502      -0.003368               0.0          0.000000            1.000000
# 148503      -0.003363               0.0          0.000000            1.000000
# 148504      -0.003380               0.0          0.000000            1.000000
# 148505      -0.003381               0.0          0.000000            1.000000
#
# [148506 rows x 4 columns]

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite://',echo = False)

# %% [markdown]
# Need to comment the code below because the sqlit database name has been created already and it does not duplicate, so it will throw an error if reran.

# %%
#conn = sql.connect('sql_df.db')
#sql_df.to_sql('sqlite_df', conn)

# %% [markdown]
# Code below to read the database in my notebook

# %%
conn = sql.connect('sqlite_df.db')
sql_db = pd.read_sql('SELECT * FROM sql_df WHERE Satisfaction_score == 1', conn)

# %%
sql_db
# Out:
#          index  MSISDN/Number  Engagement_score  Experience_score  \
# 0            0      -0.003363         -0.063274          -0.19422
# 1            1      -0.003356         -0.063274          -0.19422
# 2            2      -0.003324         -0.063274          -0.19422
# 3            3      -0.003328         -0.063274          -0.19422
# 4            4      -0.003348         -0.063274          -0.19422
# ...        ...            ...               ...               ...
# 139454  148501      -0.003361         -0.063274          -0.19422
# 139455  148502      -0.003368         -0.063274          -0.19422
# 139456  148503      -0.003363         -0.063274          -0.19422
# 139457  148504      -0.003380         -0.063274          -0.19422
# 139458  148505      -0.003381         -0.063274          -0.19422
#
#         Satisfaction_score
# 0                      1.0
# 1                      1.0
# 2                      1.0
# 3                      1.0
# 4                      1.0
# ...                    ...
# 139454                 1.0
# 139455                 1.0
# 139456                 1.0
# 139457                 1.0
# 139458                 1.0
#
# [139459 rows x 5 columns]

# %% [markdown]
# ## Task 4.7

# %% [markdown]
# Create files to export model as, for deployment purpose.

# %%
import pickle
with open('model_pkl_1', 'wb') as files:
    pickle.dump(lin_reg, files)

# %%
import joblib

# %%
joblib.dump(lin_reg, 'model_joblib')
# Out:
# ['model_joblib']
